# %% [markdown]
# #Would you use "blue" or "circle"? (Frank & Goodman, 2012)
#
# Lexicon, M, defining the relations between signals referents where rows represent the 4 possible signals: blue, green, circle, square and columns the 3 possible referents: blue square, blue circle, green square
#
# ![Screen Shot 2022-01-04 at 2.42.19 PM.png](data:image/png;base64,...)

# %%
M = [[1, 1, 0],  # blue
     [0, 0, 1],  # green
     [0, 1, 0],  # circle
     [1, 0, 1]]  # square
print("M = ", M)

# %% [markdown]
# ###Literal speaker, S0

# %%
import numpy as np

S0 = M / np.sum(M, axis=0);
print("S0 = ", S0)

S0_bluecircle = S0[:,1]; # preferred signal(s) for referring to the blue circle (note, 50-50)
print("S0_bluecircle = ", S0_bluecircle)

# %% [markdown]
# ###Literal listener, L0

# %%
L0 = M / np.sum(M,axis=1)[:,None] # probability distribution over referents given possible signals
print("L0 = ", L0)

# %% [markdown]
# ###Pragmatic speaker, S1

# %%
S1 = L0 / np.sum(L0, axis=0); # taking into account a literal listener
print("S1 = ", S1)

S1_bluecircle = S1[:,1]; # preferred signal(s) for referring to the blue circle
print("S1_bluecircle = ", S1_bluecircle)

# %% [markdown]
# #Which object are they referring to using the word "blue"? (Frank & Goodman,
#
# ---
#
# 2012)
#
# ![Screen Shot 2022-01-09 at 3.22.41 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### Pragmatic listener, L1

# %%
L1 = S1 / np.sum(S1, axis=1)[:,None] # as L0, but taking into account a pragmatic speaker
print("L1 = ", L1)

L1_blue = L1[0,:] # most likely referent for blue (1st row)
print("L1_blue = ", L1_blue)

# %% [markdown]
# # Whom is referred to with "red hair"? (Breakout session)
# 1) Specify the lexicon (use the powerpoint slide)

# %%
M = [[], # red hair
     [], # tall one
     []] # gamer

# %% [markdown]
# 2) Compute a literal listener's (L0) inference

# %%
L0 = 'do something here'

# %% [markdown]
# 3) Compute a pragmatic listener's (L1) inference

# %%
S1 = 'do something here'
L1 = 'do something here'
